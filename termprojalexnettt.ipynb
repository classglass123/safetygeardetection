# %%
# ---------------------------
# Imports
# ---------------------------
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import wandb

# ---------------------------
# W&B login (make sure you've logged in)
# ---------------------------
wandb.login()

# ---------------------------
# Hyperparameters and options
# ---------------------------
models_to_run = ['alexnet', 'resnet18']  # only AlexNet and ResNet18
batch_sizes = [16, 64]
learning_rates = [0.001, 0.0001]
augment_options = [True, False]
num_epochs = 5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------------------
# Dataset (example: ImageFolder)
# Replace 'path_to_data' with your dataset path
# ---------------------------
def get_data_loaders(batch_size, augment):
    if augment:
        transform = transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(10),
            transforms.ToTensor()
        ])
    else:
        transform = transforms.Compose([transforms.ToTensor()])

    train_dataset = datasets.ImageFolder(train_folder, transform=transform)
    val_dataset = datasets.ImageFolder(val_folder, transform=transforms.ToTensor())

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader

# ---------------------------
# Training function
# ---------------------------
def train_model(model_name, batch_size, lr, augment):
    run_name = f"{model_name}_bs{batch_size}_lr{lr}_aug{augment}"
    wandb.init(project="safety_gear_detection_auto", name=run_name)

    train_loader, val_loader = get_data_loaders(batch_size, augment)

    # Load model
    if model_name == 'alexnet':
        model = models.alexnet(weights=models.AlexNet_Weights.DEFAULT)
    elif model_name == 'resnet18':
        model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
        # Replace final layer for number of classes
        num_features = model.fc.in_features
        model.fc = nn.Linear(num_features, 2)  # replace 2 with your number of classes

    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_acc = correct_train / total_train
        train_loss = running_loss / len(train_loader)

        # Validation
        model.eval()
        correct_val = 0
        total_val = 0
        val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_acc = correct_val / total_val
        val_loss = val_loss / len(val_loader)

        print(f"{run_name} | Epoch {epoch+1}/{num_epochs} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

        wandb.log({
            "epoch": epoch+1,
            "train_acc": train_acc,
            "train_loss": train_loss,
            "val_acc": val_acc,
            "val_loss": val_loss
        })

    wandb.finish()

# ---------------------------
# Run all experiments
# ---------------------------
for model_name in models_to_run:
    for bs in batch_sizes:
        for lr in learning_rates:
            for aug in augment_options:
                train_model(model_name=model_name, batch_size=bs, lr=lr, augment=aug)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▅█</td></tr><tr><td>train_acc</td><td>▁▇█</td></tr><tr><td>train_loss</td><td>█▅▁</td></tr><tr><td>val_acc</td><td>█▁▁</td></tr><tr><td>val_loss</td><td>█▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>3</td></tr><tr><td>train_acc</td><td>0.55</td></tr><tr><td>train_loss</td><td>1.20953</td></tr><tr><td>val_acc</td><td>0.5</td></tr><tr><td>val_loss</td><td>0.92966</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs16_lr0.001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/mk7uaoyb' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/mk7uaoyb</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_111641-mk7uaoyb/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_111729-uz55o481</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/uz55o481' target="_blank">alexnet_bs16_lr0.001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/uz55o481' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/uz55o481</a>
# alexnet_bs16_lr0.001_augTrue | Epoch 1/5 | Train Acc: 0.2750 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augTrue | Epoch 2/5 | Train Acc: 0.4250 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augTrue | Epoch 3/5 | Train Acc: 0.4000 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augTrue | Epoch 4/5 | Train Acc: 0.4250 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augTrue | Epoch 5/5 | Train Acc: 0.4500 | Val Acc: 0.5000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▇▆▇█</td></tr><tr><td>train_loss</td><td>▅▃█▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃█▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.45</td></tr><tr><td>train_loss</td><td>1.32087</td></tr><tr><td>val_acc</td><td>0.5</td></tr><tr><td>val_loss</td><td>0.77669</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs16_lr0.001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/uz55o481' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/uz55o481</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_111729-uz55o481/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_111813-2yymd0xo</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/2yymd0xo' target="_blank">alexnet_bs16_lr0.001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/2yymd0xo' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/2yymd0xo</a>
# alexnet_bs16_lr0.001_augFalse | Epoch 1/5 | Train Acc: 0.3500 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augFalse | Epoch 2/5 | Train Acc: 0.5250 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augFalse | Epoch 3/5 | Train Acc: 0.5750 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augFalse | Epoch 4/5 | Train Acc: 0.3500 | Val Acc: 0.5000
# alexnet_bs16_lr0.001_augFalse | Epoch 5/5 | Train Acc: 0.5000 | Val Acc: 0.5000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▆█▁▆</td></tr><tr><td>train_loss</td><td>█▅▁▂▅</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇▂▁█▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.5</td></tr><tr><td>train_loss</td><td>3.91095</td></tr><tr><td>val_acc</td><td>0.5</td></tr><tr><td>val_loss</td><td>1.22096</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs16_lr0.001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/2yymd0xo' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/2yymd0xo</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_111813-2yymd0xo/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_111854-xca436zf</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/xca436zf' target="_blank">alexnet_bs16_lr0.0001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/xca436zf' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/xca436zf</a>
# alexnet_bs16_lr0.0001_augTrue | Epoch 1/5 | Train Acc: 0.0500 | Val Acc: 0.5000
# alexnet_bs16_lr0.0001_augTrue | Epoch 2/5 | Train Acc: 0.6000 | Val Acc: 0.7000
# alexnet_bs16_lr0.0001_augTrue | Epoch 3/5 | Train Acc: 0.8750 | Val Acc: 0.8000
# alexnet_bs16_lr0.0001_augTrue | Epoch 4/5 | Train Acc: 0.9000 | Val Acc: 0.8000
# alexnet_bs16_lr0.0001_augTrue | Epoch 5/5 | Train Acc: 0.9750 | Val Acc: 0.9000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▅▇▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▅▆▆█</td></tr><tr><td>val_loss</td><td>█▄▄▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.975</td></tr><tr><td>train_loss</td><td>0.07802</td></tr><tr><td>val_acc</td><td>0.9</td></tr><tr><td>val_loss</td><td>0.22488</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs16_lr0.0001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/xca436zf' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/xca436zf</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_111854-xca436zf/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_111934-euzk1us8</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/euzk1us8' target="_blank">alexnet_bs16_lr0.0001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/euzk1us8' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/euzk1us8</a>
# alexnet_bs16_lr0.0001_augFalse | Epoch 1/5 | Train Acc: 0.1000 | Val Acc: 0.5000
# alexnet_bs16_lr0.0001_augFalse | Epoch 2/5 | Train Acc: 0.6750 | Val Acc: 0.8000
# alexnet_bs16_lr0.0001_augFalse | Epoch 3/5 | Train Acc: 0.9250 | Val Acc: 0.8000
# alexnet_bs16_lr0.0001_augFalse | Epoch 4/5 | Train Acc: 0.9000 | Val Acc: 0.9000
# alexnet_bs16_lr0.0001_augFalse | Epoch 5/5 | Train Acc: 1.0000 | Val Acc: 0.9000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▅▇▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▆▆██</td></tr><tr><td>val_loss</td><td>█▃▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.02145</td></tr><tr><td>val_acc</td><td>0.9</td></tr><tr><td>val_loss</td><td>0.3083</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs16_lr0.0001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/euzk1us8' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/euzk1us8</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_111934-euzk1us8/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112015-yemj3v7f</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/yemj3v7f' target="_blank">alexnet_bs64_lr0.001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/yemj3v7f' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/yemj3v7f</a>
# alexnet_bs64_lr0.001_augTrue | Epoch 1/5 | Train Acc: 0.0000 | Val Acc: 0.5000
# alexnet_bs64_lr0.001_augTrue | Epoch 2/5 | Train Acc: 0.5000 | Val Acc: 0.5000
# alexnet_bs64_lr0.001_augTrue | Epoch 3/5 | Train Acc: 0.5000 | Val Acc: 0.4000
# alexnet_bs64_lr0.001_augTrue | Epoch 4/5 | Train Acc: 0.4500 | Val Acc: 0.4000
# alexnet_bs64_lr0.001_augTrue | Epoch 5/5 | Train Acc: 0.5500 | Val Acc: 0.5000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▇▄▁</td></tr><tr><td>val_acc</td><td>██▁▁█</td></tr><tr><td>val_loss</td><td>▂█▄▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.55</td></tr><tr><td>train_loss</td><td>0.78654</td></tr><tr><td>val_acc</td><td>0.5</td></tr><tr><td>val_loss</td><td>6.15036</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs64_lr0.001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/yemj3v7f' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/yemj3v7f</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112015-yemj3v7f/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112046-s4n4w8s1</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s4n4w8s1' target="_blank">alexnet_bs64_lr0.001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s4n4w8s1' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s4n4w8s1</a>
# alexnet_bs64_lr0.001_augFalse | Epoch 1/5 | Train Acc: 0.0000 | Val Acc: 0.6000
# alexnet_bs64_lr0.001_augFalse | Epoch 2/5 | Train Acc: 0.6750 | Val Acc: 0.5000
# alexnet_bs64_lr0.001_augFalse | Epoch 3/5 | Train Acc: 0.5000 | Val Acc: 0.5000
# alexnet_bs64_lr0.001_augFalse | Epoch 4/5 | Train Acc: 0.5250 | Val Acc: 0.5000
# alexnet_bs64_lr0.001_augFalse | Epoch 5/5 | Train Acc: 0.5000 | Val Acc: 0.5000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁█▆▆▆</td></tr><tr><td>train_loss</td><td>▇▁█▃▂</td></tr><tr><td>val_acc</td><td>█▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁█▃▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.5</td></tr><tr><td>train_loss</td><td>2.77705</td></tr><tr><td>val_acc</td><td>0.5</td></tr><tr><td>val_loss</td><td>2.7468</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs64_lr0.001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s4n4w8s1' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s4n4w8s1</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112046-s4n4w8s1/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112116-cvrcen3h</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/cvrcen3h' target="_blank">alexnet_bs64_lr0.0001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/cvrcen3h' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/cvrcen3h</a>
# alexnet_bs64_lr0.0001_augTrue | Epoch 1/5 | Train Acc: 0.0000 | Val Acc: 0.1000
# alexnet_bs64_lr0.0001_augTrue | Epoch 2/5 | Train Acc: 0.1750 | Val Acc: 0.5000
# alexnet_bs64_lr0.0001_augTrue | Epoch 3/5 | Train Acc: 0.5750 | Val Acc: 0.6000
# alexnet_bs64_lr0.0001_augTrue | Epoch 4/5 | Train Acc: 0.7000 | Val Acc: 0.7000
# alexnet_bs64_lr0.0001_augTrue | Epoch 5/5 | Train Acc: 0.6750 | Val Acc: 0.7000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▃▇██</td></tr><tr><td>train_loss</td><td>█▄▂▁▁</td></tr><tr><td>val_acc</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▃▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.675</td></tr><tr><td>train_loss</td><td>0.79447</td></tr><tr><td>val_acc</td><td>0.7</td></tr><tr><td>val_loss</td><td>0.5423</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs64_lr0.0001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/cvrcen3h' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/cvrcen3h</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112116-cvrcen3h/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112146-1op7d0vl</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/1op7d0vl' target="_blank">alexnet_bs64_lr0.0001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/1op7d0vl' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/1op7d0vl</a>
# alexnet_bs64_lr0.0001_augFalse | Epoch 1/5 | Train Acc: 0.0000 | Val Acc: 0.1000
# alexnet_bs64_lr0.0001_augFalse | Epoch 2/5 | Train Acc: 0.1250 | Val Acc: 0.5000
# alexnet_bs64_lr0.0001_augFalse | Epoch 3/5 | Train Acc: 0.6250 | Val Acc: 0.8000
# alexnet_bs64_lr0.0001_augFalse | Epoch 4/5 | Train Acc: 0.8750 | Val Acc: 0.8000
# alexnet_bs64_lr0.0001_augFalse | Epoch 5/5 | Train Acc: 0.7750 | Val Acc: 0.9000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▂▆█▇</td></tr><tr><td>train_loss</td><td>█▄▂▁▁</td></tr><tr><td>val_acc</td><td>▁▅▇▇█</td></tr><tr><td>val_loss</td><td>█▃▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.775</td></tr><tr><td>train_loss</td><td>0.52001</td></tr><tr><td>val_acc</td><td>0.9</td></tr><tr><td>val_loss</td><td>0.28157</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_bs64_lr0.0001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/1op7d0vl' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/1op7d0vl</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112146-1op7d0vl/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112219-6llpl8ya</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/6llpl8ya' target="_blank">resnet18_bs16_lr0.001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/6llpl8ya' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/6llpl8ya</a>
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 83.5MB/s]
# resnet18_bs16_lr0.001_augTrue | Epoch 1/5 | Train Acc: 0.6500 | Val Acc: 0.5000
# resnet18_bs16_lr0.001_augTrue | Epoch 2/5 | Train Acc: 0.9250 | Val Acc: 0.5000
# resnet18_bs16_lr0.001_augTrue | Epoch 3/5 | Train Acc: 0.9500 | Val Acc: 0.8000
# resnet18_bs16_lr0.001_augTrue | Epoch 4/5 | Train Acc: 0.9500 | Val Acc: 0.5000
# resnet18_bs16_lr0.001_augTrue | Epoch 5/5 | Train Acc: 0.9500 | Val Acc: 0.5000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▇███</td></tr><tr><td>train_loss</td><td>█▄▂▁▃</td></tr><tr><td>val_acc</td><td>▁▁█▁▁</td></tr><tr><td>val_loss</td><td>▂▅▁█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.95</td></tr><tr><td>train_loss</td><td>0.21708</td></tr><tr><td>val_acc</td><td>0.5</td></tr><tr><td>val_loss</td><td>11.44249</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs16_lr0.001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/6llpl8ya' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/6llpl8ya</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112219-6llpl8ya/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112321-k1v27m37</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/k1v27m37' target="_blank">resnet18_bs16_lr0.001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/k1v27m37' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/k1v27m37</a>
# resnet18_bs16_lr0.001_augFalse | Epoch 1/5 | Train Acc: 0.6500 | Val Acc: 1.0000
# resnet18_bs16_lr0.001_augFalse | Epoch 2/5 | Train Acc: 0.9500 | Val Acc: 0.8000
# resnet18_bs16_lr0.001_augFalse | Epoch 3/5 | Train Acc: 0.9750 | Val Acc: 0.5000
# resnet18_bs16_lr0.001_augFalse | Epoch 4/5 | Train Acc: 0.9500 | Val Acc: 0.7000
# resnet18_bs16_lr0.001_augFalse | Epoch 5/5 | Train Acc: 0.9750 | Val Acc: 0.8000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▇█▇█</td></tr><tr><td>train_loss</td><td>█▄▁▂▁</td></tr><tr><td>val_acc</td><td>█▅▁▄▅</td></tr><tr><td>val_loss</td><td>▁▂█▄▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>0.975</td></tr><tr><td>train_loss</td><td>0.0731</td></tr><tr><td>val_acc</td><td>0.8</td></tr><tr><td>val_loss</td><td>3.92444</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs16_lr0.001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/k1v27m37' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/k1v27m37</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112321-k1v27m37/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112421-dulmeipu</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/dulmeipu' target="_blank">resnet18_bs16_lr0.0001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/dulmeipu' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/dulmeipu</a>
# resnet18_bs16_lr0.0001_augTrue | Epoch 1/5 | Train Acc: 0.6750 | Val Acc: 0.7000
# resnet18_bs16_lr0.0001_augTrue | Epoch 2/5 | Train Acc: 0.9250 | Val Acc: 0.8000
# resnet18_bs16_lr0.0001_augTrue | Epoch 3/5 | Train Acc: 0.9500 | Val Acc: 0.9000
# resnet18_bs16_lr0.0001_augTrue | Epoch 4/5 | Train Acc: 1.0000 | Val Acc: 0.9000
# resnet18_bs16_lr0.0001_augTrue | Epoch 5/5 | Train Acc: 1.0000 | Val Acc: 0.9000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▆▇██</td></tr><tr><td>train_loss</td><td>█▄▂▂▁</td></tr><tr><td>val_acc</td><td>▁▅███</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.01972</td></tr><tr><td>val_acc</td><td>0.9</td></tr><tr><td>val_loss</td><td>0.18716</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs16_lr0.0001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/dulmeipu' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/dulmeipu</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112421-dulmeipu/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112522-pjnv5hdj</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/pjnv5hdj' target="_blank">resnet18_bs16_lr0.0001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/pjnv5hdj' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/pjnv5hdj</a>
# resnet18_bs16_lr0.0001_augFalse | Epoch 1/5 | Train Acc: 0.7000 | Val Acc: 0.9000
# resnet18_bs16_lr0.0001_augFalse | Epoch 2/5 | Train Acc: 1.0000 | Val Acc: 0.9000
# resnet18_bs16_lr0.0001_augFalse | Epoch 3/5 | Train Acc: 1.0000 | Val Acc: 0.9000
# resnet18_bs16_lr0.0001_augFalse | Epoch 4/5 | Train Acc: 1.0000 | Val Acc: 0.9000
# resnet18_bs16_lr0.0001_augFalse | Epoch 5/5 | Train Acc: 1.0000 | Val Acc: 0.9000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁████</td></tr><tr><td>train_loss</td><td>█▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▅▄▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.01282</td></tr><tr><td>val_acc</td><td>0.9</td></tr><tr><td>val_loss</td><td>0.2998</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs16_lr0.0001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/pjnv5hdj' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/pjnv5hdj</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112522-pjnv5hdj/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112622-s3em9nqf</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s3em9nqf' target="_blank">resnet18_bs64_lr0.001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s3em9nqf' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s3em9nqf</a>
# resnet18_bs64_lr0.001_augTrue | Epoch 1/5 | Train Acc: 0.4750 | Val Acc: 0.7000
# resnet18_bs64_lr0.001_augTrue | Epoch 2/5 | Train Acc: 0.9750 | Val Acc: 0.9000
# resnet18_bs64_lr0.001_augTrue | Epoch 3/5 | Train Acc: 1.0000 | Val Acc: 0.8000
# resnet18_bs64_lr0.001_augTrue | Epoch 4/5 | Train Acc: 1.0000 | Val Acc: 0.8000
# resnet18_bs64_lr0.001_augTrue | Epoch 5/5 | Train Acc: 1.0000 | Val Acc: 0.7000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁████</td></tr><tr><td>train_loss</td><td>█▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁█▅▅▁</td></tr><tr><td>val_loss</td><td>▂▁▃▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.00431</td></tr><tr><td>val_acc</td><td>0.7</td></tr><tr><td>val_loss</td><td>2.41779</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs64_lr0.001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s3em9nqf' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/s3em9nqf</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112622-s3em9nqf/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112725-ang5qqqn</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/ang5qqqn' target="_blank">resnet18_bs64_lr0.001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/ang5qqqn' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/ang5qqqn</a>
# resnet18_bs64_lr0.001_augFalse | Epoch 1/5 | Train Acc: 0.4750 | Val Acc: 0.6000
# resnet18_bs64_lr0.001_augFalse | Epoch 2/5 | Train Acc: 1.0000 | Val Acc: 0.8000
# resnet18_bs64_lr0.001_augFalse | Epoch 3/5 | Train Acc: 1.0000 | Val Acc: 1.0000
# resnet18_bs64_lr0.001_augFalse | Epoch 4/5 | Train Acc: 1.0000 | Val Acc: 1.0000
# resnet18_bs64_lr0.001_augFalse | Epoch 5/5 | Train Acc: 1.0000 | Val Acc: 0.7000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁████</td></tr><tr><td>train_loss</td><td>█▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▅██▃</td></tr><tr><td>val_loss</td><td>█▅▁▂▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.00048</td></tr><tr><td>val_acc</td><td>0.7</td></tr><tr><td>val_loss</td><td>0.54426</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs64_lr0.001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/ang5qqqn' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/ang5qqqn</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112725-ang5qqqn/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112827-du5wkynm</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/du5wkynm' target="_blank">resnet18_bs64_lr0.0001_augTrue</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/du5wkynm' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/du5wkynm</a>
# resnet18_bs64_lr0.0001_augTrue | Epoch 1/5 | Train Acc: 0.5250 | Val Acc: 0.5000
# resnet18_bs64_lr0.0001_augTrue | Epoch 2/5 | Train Acc: 0.9000 | Val Acc: 0.5000
# resnet18_bs64_lr0.0001_augTrue | Epoch 3/5 | Train Acc: 1.0000 | Val Acc: 0.5000
# resnet18_bs64_lr0.0001_augTrue | Epoch 4/5 | Train Acc: 1.0000 | Val Acc: 0.5000
# resnet18_bs64_lr0.0001_augTrue | Epoch 5/5 | Train Acc: 1.0000 | Val Acc: 0.6000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁▇███</td></tr><tr><td>train_loss</td><td>█▅▂▂▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁█</td></tr><tr><td>val_loss</td><td>▁▁▆█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.06665</td></tr><tr><td>val_acc</td><td>0.6</td></tr><tr><td>val_loss</td><td>0.57458</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs64_lr0.0001_augTrue</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/du5wkynm' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/du5wkynm</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112827-du5wkynm/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251209_112929-nu87hpih</code>
# Syncing run <strong><a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/nu87hpih' target="_blank">resnet18_bs64_lr0.0001_augFalse</a></strong> to <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a>
#  View run at <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/nu87hpih' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/nu87hpih</a>
# resnet18_bs64_lr0.0001_augFalse | Epoch 1/5 | Train Acc: 0.5500 | Val Acc: 0.7000
# resnet18_bs64_lr0.0001_augFalse | Epoch 2/5 | Train Acc: 1.0000 | Val Acc: 0.7000
# resnet18_bs64_lr0.0001_augFalse | Epoch 3/5 | Train Acc: 1.0000 | Val Acc: 0.8000
# resnet18_bs64_lr0.0001_augFalse | Epoch 4/5 | Train Acc: 1.0000 | Val Acc: 0.8000
# resnet18_bs64_lr0.0001_augFalse | Epoch 5/5 | Train Acc: 1.0000 | Val Acc: 0.8000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_acc</td><td>▁████</td></tr><tr><td>train_loss</td><td>█▃▂▁▁</td></tr><tr><td>val_acc</td><td>▁▁███</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.01523</td></tr><tr><td>val_acc</td><td>0.8</td></tr><tr><td>val_loss</td><td>0.36791</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet18_bs64_lr0.0001_augFalse</strong> at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/nu87hpih' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto/runs/nu87hpih</a><br> View project at: <a href='https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto' target="_blank">https://wandb.ai/cforbes2022-florida-atlantic-university/safety_gear_detection_auto</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251209_112929-nu87hpih/logs</code>
